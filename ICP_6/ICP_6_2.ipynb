# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')
#scale data
train_data /=255.0
test_data /=255.0
#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# (28, 28)
# 784
# Epoch 1/10
# 235/235 [==============================] - 11s 41ms/step - loss: 0.2952 - accuracy: 0.9109 - val_loss: 0.1819 - val_accuracy: 0.9402
# Epoch 2/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.1009 - accuracy: 0.9688 - val_loss: 0.0860 - val_accuracy: 0.9733
# Epoch 3/10
# 235/235 [==============================] - 8s 33ms/step - loss: 0.0638 - accuracy: 0.9797 - val_loss: 0.2075 - val_accuracy: 0.9400
# Epoch 4/10
# 235/235 [==============================] - 9s 37ms/step - loss: 0.0448 - accuracy: 0.9861 - val_loss: 0.0782 - val_accuracy: 0.9753
# Epoch 5/10
# 235/235 [==============================] - 12s 50ms/step - loss: 0.0313 - accuracy: 0.9894 - val_loss: 0.0640 - val_accuracy: 0.9804
# Epoch 6/10
# 235/235 [==============================] - 11s 49ms/step - loss: 0.0236 - accuracy: 0.9922 - val_loss: 0.0861 - val_accuracy: 0.9746
# Epoch 7/10
# 235/235 [==============================] - 13s 57ms/step - loss: 0.0168 - accuracy: 0.9948 - val_loss: 0.0625 - val_accuracy: 0.9821
# Epoch 8/10
# 235/235 [==============================] - 13s 54ms/step - loss: 0.0124 - accuracy: 0.9962 - val_loss: 0.0708 - val_accuracy: 0.9812
# Epoch 9/10
# 235/235 [==============================] - 9s 39ms/step - loss: 0.0096 - accuracy: 0.9971 - val_loss: 0.0743 - val_accuracy: 0.9810
# Epoch 10/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.0707 - val_accuracy: 0.9833

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

# select a random image from test data
image_index = 1234
img = test_images[image_index]

# plot the image
plt.imshow(img, cmap='gray')

# reshape image to 1D vector
img = img.reshape((1, 784))

# normalize pixel values
img = img / 255.0

# predict class of image
result = model.predict(img)
print("Predicted digit:", np.argmax(result))
# Out:
# 1/1 [==============================] - 0s 114ms/step
# Predicted digit: 8

# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')
#scale data
train_data /=255.0
test_data /=255.0
#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(dimData,)))
model.add(Dense(256, activation='tanh'))
model.add(Dense(128, activation='tanh'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
# Out:
# (28, 28)
# 784
# Epoch 1/10
# 235/235 [==============================] - 8s 32ms/step - loss: 0.3335 - accuracy: 0.8981 - val_loss: 0.2486 - val_accuracy: 0.9202
# Epoch 2/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.1480 - accuracy: 0.9558 - val_loss: 0.1180 - val_accuracy: 0.9647
# Epoch 3/10
# 235/235 [==============================] - 7s 29ms/step - loss: 0.0968 - accuracy: 0.9702 - val_loss: 0.1225 - val_accuracy: 0.9619
# Epoch 4/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.0720 - accuracy: 0.9782 - val_loss: 0.0867 - val_accuracy: 0.9716
# Epoch 5/10
# 235/235 [==============================] - 7s 28ms/step - loss: 0.0540 - accuracy: 0.9836 - val_loss: 0.1067 - val_accuracy: 0.9664
# Epoch 6/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.0404 - accuracy: 0.9874 - val_loss: 0.0804 - val_accuracy: 0.9745
# Epoch 7/10
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0309 - accuracy: 0.9907 - val_loss: 0.0813 - val_accuracy: 0.9746
# Epoch 8/10
# 235/235 [==============================] - 6s 26ms/step - loss: 0.0237 - accuracy: 0.9928 - val_loss: 0.0741 - val_accuracy: 0.9771
# Epoch 9/10
# 235/235 [==============================] - 6s 24ms/step - loss: 0.0162 - accuracy: 0.9955 - val_loss: 0.0731 - val_accuracy: 0.9781
# Epoch 10/10
# 235/235 [==============================] - 8s 32ms/step - loss: 0.0131 - accuracy: 0.9963 - val_loss: 0.0706 - val_accuracy: 0.9789

# %%
from keras import Sequential
from keras.datasets import mnist
import numpy as np
from keras.layers import Dense
from keras.utils import to_categorical

(train_images,train_labels),(test_images, test_labels) = mnist.load_data()

print(train_images.shape[1:])
#process the data
#1. convert each image of shape 28*28 to 784 dimensional which will be fed to the network as a single feature
dimData = np.prod(train_images.shape[1:])
print(dimData)
train_data = train_images.reshape(train_images.shape[0],dimData)
test_data = test_images.reshape(test_images.shape[0],dimData)

#convert data to float and scale values between 0 and 1
train_data = train_data.astype('float')
test_data = test_data.astype('float')

#change the labels frominteger to one-hot encoding. to_categorical is doing the same thing as LabelEncoder()
train_labels_one_hot = to_categorical(train_labels)
test_labels_one_hot = to_categorical(test_labels)

#creating network
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(dimData,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, train_labels_one_hot, batch_size=256, epochs=10, verbose=1,
                   validation_data=(test_data, test_labels_one_hot))
test_loss, test_acc = model.evaluate(test_data, test_labels_one_hot, verbose=0)
print(f'Test loss: {test_loss:.3f}, Test accuracy: {test_acc:.3f}')
# Out:
# (28, 28)
# 784
# Epoch 1/10
# 235/235 [==============================] - 12s 45ms/step - loss: 6.2064 - accuracy: 0.8765 - val_loss: 1.0673 - val_accuracy: 0.9073
# Epoch 2/10
# 235/235 [==============================] - 8s 35ms/step - loss: 0.4216 - accuracy: 0.9449 - val_loss: 0.3504 - val_accuracy: 0.9458
# Epoch 3/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.2309 - accuracy: 0.9595 - val_loss: 0.2751 - val_accuracy: 0.9535
# Epoch 4/10
# 235/235 [==============================] - 7s 32ms/step - loss: 0.1755 - accuracy: 0.9669 - val_loss: 0.3386 - val_accuracy: 0.9510
# Epoch 5/10
# 235/235 [==============================] - 6s 26ms/step - loss: 0.1559 - accuracy: 0.9722 - val_loss: 0.3238 - val_accuracy: 0.9603
# Epoch 6/10
# 235/235 [==============================] - 8s 32ms/step - loss: 0.1357 - accuracy: 0.9766 - val_loss: 0.2801 - val_accuracy: 0.9635
# Epoch 7/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.1294 - accuracy: 0.9783 - val_loss: 0.3554 - val_accuracy: 0.9631
# Epoch 8/10
# 235/235 [==============================] - 8s 33ms/step - loss: 0.1102 - accuracy: 0.9816 - val_loss: 0.3032 - val_accuracy: 0.9682
# Epoch 9/10
# 235/235 [==============================] - 6s 27ms/step - loss: 0.1022 - accuracy: 0.9837 - val_loss: 0.2978 - val_accuracy: 0.9679
# Epoch 10/10
#   9/235 [>.............................] - ETA: 5s - loss: 0.0838 - accuracy: 0.9848
